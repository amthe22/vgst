# %%
import pandas as pd

# %%
tbdata=pd.read_excel("Bondel data.xlsx")
x=tbdata.dropna()
x.count()
# Out:
#                          32
# Age                      32
# Gender                   32
# Passive/Active           32
# Blood Sample No.         32
# Blood Collection Date    32
# Test Date                32
# Result                   32
# From                     32
# To                       32
# dtype: int64

# %%
data=['Age','Gender','Passive/Active','Result']
tbdata=tbdata[data]
tbdata.dropna()
# Out:
#       Age  Gender Passive/Active                  Result
# 0    26.0    Male        Passive                  PV(Tg)
# 1    19.0  Female        Passive  MIXED INFECTION PV(Tg)
# 2    23.0    Male        Passive                  PV(Tg)
# 3    43.0    Male        Passive                  PV(Tg)
# 4    50.0    Male        Passive                  PV(Tg)
# 5    39.0    Male        Passive                  PV(Tg)
# 6    26.0    Male        Passive                  PV(Tg)
# 7    24.0    Male        Passive                  PV(Tg)
# 8    60.0    Male        Passive                  PV(Tg)
# 9    27.0    Male        Passive                  PV(Tg)
# 10   13.0    Male        Passive                  PV(Tg)
# 11   24.0    Male        Passive                  PV(Tg)
# 12   32.0  Female        Passive                  PV(Tg)
# 13   25.0  Female        Passive                  PV(Tg)
# 14    2.0  Female        Passive                  PV(Tg)
# ...
