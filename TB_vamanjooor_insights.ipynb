# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("vgst/vamanjur/TBHospitalVamajurdata.csv")
agedata=data[["Age","Gender"]]
agedata['Gender']=agedata['Gender'].replace(['F','M'],['f','m'])
agedata
# Out:
# C:\Users\Abin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Age Gender
# 0    44.0      m
# 1    40.0      m
# 2    63.0      m
# 3    38.0      f
# 4    40.0      m
# 5    37.0      m
# 6    40.0      m
# 7    38.0      m
# 8    38.0      m
# 9    45.0      m
# 10   36.0      m
# 11   27.0      m
# 12   43.0      m
# 13   48.0      m
# 14   54.0      m
# 15   70.0      m
# 16   59.0      m
# 17   36.0      m
# 18   70.0      f
# 19   44.0      m
# 20   55.0      f
# 21   36.0      m
# 22   43.0      m
# 23   60.0      m
# 24   49.0      f
# 25   53.0      m
# 26   53.0      m
# 27   40.0      m
# 28   63.0      m
# ...

# %%
import matplotlib.pyplot as plt

# %%
counts = agedata.groupby('Age')['Gender'].count()
countage=agedata.groupby('Age').count()
countage.plot.pie(subplots=True)
plt.show()

# %%
counts.plot.bar(subplots=True,figsize=(10,5))
plt.legend()
plt.show()

# %%
gen=agedata.groupby('Gender').count()
gen.plot.pie(subplots=True)
plt.show()
