# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py

# %%
data=pd.read_csv('data.csv')
data.dropna()

data.head()
# Out:
#      Disease      County  Year     Sex  Count  Population   Rate  CI.lower  \
# 0  Amebiasis  California  2001  Female    176    17339700  1.015     0.871
# 1  Amebiasis  California  2001    Male    365    17173042  2.125     1.913
# 2  Amebiasis  California  2001   Total    541    34512742  1.568     1.438
# 3  Amebiasis  California  2002  Female    145    17554666  0.826     0.697
# 4  Amebiasis  California  2002    Male    279    17383624  1.605     1.422
#
#    CI.upper Unstable
# 0     1.177
# 1     2.355
# 2     1.705
# 3     0.972
# 4     1.805

# %%
req=['Disease','Count']
data_d=data[req]
data_d=pd.get_dummies(data_d)
data_d.head()
# Out:
#    Count  Disease_Amebiasis  Disease_Anaplasmosis and Ehrlichiosis  \
# 0    176                  1                                      0
# 1    365                  1                                      0
# 2    541                  1                                      0
# 3    145                  1                                      0
# 4    279                  1                                      0
#
#    Disease_Anthrax  Disease_Babesiosis  Disease_Botulism, Foodborne  \
# 0                0                   0                            0
# 1                0                   0                            0
# 2                0                   0                            0
# 3                0                   0                            0
# 4                0                   0                            0
#
#    Disease_Botulism, Infant  Disease_Botulism, Other  Disease_Botulism, Wound  \
# ...

# %%
data_d.plot.pie(subplots=True)
py.show()
